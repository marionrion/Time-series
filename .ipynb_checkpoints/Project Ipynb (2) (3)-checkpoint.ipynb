# %% [markdown]
# # PHASE 4 PROJECT: GROUP 3
#
# ## **Project Title: Time Series Modelling of Real Estate Value**
#
# ### **Team Members**
# - **Joan Nyamache**
# - **Marion Achieng**
# - **Eugene Marius**
#
#
# ### **Introduction**
#
# Real estate encompasses land, any structures on it, and the natural resources within its boundaries. This sector is pivotal to the economy, offering substantial investment opportunities. Our project aims to assist a real estate development company in constructing residential homes in the United States with favorable returns on investment. By leveraging extensive datasets from Zillow, a leading real estate firm, we will develop a time series model to guide informed investment decisions.
#
# ---
#
# ## **Project Title: Time Series Modelling of Real Estate Value**
# ![image-2.png](attachment:image-2.png)
#
# *Figure 1: A visual representation of the real estate market, featuring a city skyline and an overlay of trend graphs. This image symbolizes the analysis of real estate data and trends, reflecting the focus of our time series modeling project.*
#
#
# ---
#
# ### Business Understanding
# Investing in real estate is both dynamic and lucrative, requiring meticulous research and strategic planning. Our stakeholder, a fictional real estate investment company, seeks to identify the top five most promising postal codes (zip codes) for future investments. Utilizing historical data from Zillow, we will analyze trends to highlight these promising areas.
#
# ---
#
# ### Problem Statement
# The goal of this project is to support a real estate development company in identifying high-potential areas in the United States for constructing residential properties. Through time series analysis of historical housing data from Zillow, we aim to uncover trends and predict future housing prices, guiding investment decisions to maximize financial returns.
#
# ---
#
# ### Objectives
# 1. **Identify the Top 5 Zip Codes for Investment:** Determine the most promising postal codes based on historical data.
# 2. **Forecast Future House Prices:** Predict future house prices in these top zip codes.
# 3. **Provide Actionable Insights and Strategic Recommendations:** Offer insights and advice for making informed investment decisions.
#
# ---
#
# ### Data Understanding
#
# The dataset for this analysis is sourced from Zillow and contains detailed historical housing data. It encompasses a total of 14,723 rows and 272 columns, structured in a wide format.
#
# #### Dataset Overview:
#
# - **Source:** Zillow Website
# - **Total Rows:** 14,723
# - **Total Columns:** 272
#
# #### Column Details:
#
# - **`RegionID`**: A unique identifier assigned to each region.
#   *Data Type:* Integer (`int64`)
#
# - **`RegionName`**: The name of the region, which also represents the ZIP code.
#   *Data Type:* Integer (`int64`)
#
# - **`City`**: The city where the region is situated.
#   *Data Type:* String (`object`)
#
# - **`State`**: The state in which the region is located.
#   *Data Type:* String (`object`)
#
# - **`Metro`**: The metropolitan area associated with the region, if applicable.
#   *Data Type:* String (`object`)
#
# - **`CountyName`**: The county where the region is found.
#   *Data Type:* String (`object`)
#
# - **`SizeRank`**: A numerical rank indicating the size of the region relative to other regions in the dataset.
#   *Data Type:* Integer (`int64`)
#
# - **`1996 to 2018`**: Monthly median home prices for the region spanning from January 2000 to August 2022.
#   *Data Type:* Float (`float64`)
#
# This dataset provides comprehensive coverage of historical housing market trends and allows for a thorough analysis of regional price movements over time.
#
# ---
#
#
# - **268 Numerical Columns:**
#   - Monthly Median Housing Prices: From January 2000 to August 2022, covering 274 data points of monthly data for each zip code.
#
# ---
#
# **Project Plan Overview**
#
# In this project, we shall seek to do the following:
#
# 1. **Load the Dataset**
#    - **Description:** Import the dataset into our working environment to begin analysis. This will involve reading data from CSV files, databases, or other sources.
#
# 2. **Understand the Dataset**
#    - **Description:** Conduct an initial exploration to comprehend the structure, types of data, and basic statistics. This helps in identifying potential issues and understanding the context.
#
# 3. **Choose Our Target Variable**
#    - **Description:** Identify the dependent variable that we aim to predict or analyze. This variable will be the focus of our modeling efforts.
#
# 4. **Prepare the Dataset**
#    - **Description:** Clean and preprocess the data to ensure it's suitable for analysis. This includes handling missing values, outliers, and checking for multicollinearity.
#      - **Example:** Cleaning the dataset, checking for multicollinearity.
#
# 5. **Encode Our Categorical Variables**
#    - **Description:** Transform categorical data into a numerical format that can be used in machine learning models. This may involve techniques like one-hot encoding or label encoding.
#
# 6. **Build the ARIMA Model**
#    - **Description:** Develop an ARIMA (AutoRegressive Integrated Moving Average) model for time series forecasting. This involves identifying the optimal parameters and fitting the model to the data.
#
# 7. **Evaluate the ARIMA Model**
#    - **Description:** Assess the performance of the ARIMA model using appropriate metrics such as AIC (Akaike Information Criterion), BIC (Bayesian Information Criterion), and RMSE (Root Mean Square Error). This helps in ensuring the model's accuracy and reliability.
#
# 8. **Use the ARIMA Model for Prediction**
#    - **Description:** Apply the ARIMA model to make predictions on new or unseen data. This step validates the model's practical applicability.
#
# 9. **Come Up with Relevant Findings**
#    - **Description:** Summarize the insights gained from the analysis and model predictions. Highlight significant patterns, trends, and actionable recommendations.
# ---
#
# **Data Understanding**
#
# Our dataset includes various pieces of information related to real estate. It has the following attributes:
#
# - **RegionID:** An identifier for each region.
# - **RegionName:** The name of the region.
# - **City:** The city where the region is located.
# - **State:** The state where the city is located.
# - **Metro:** The metropolitan area of the region.
# - **SizeRank:** The size ranking of the region.
# - **CountyName:** The name of the county.
# - **Value:** The real estate prices in the region.
#
# We are using the Zillow Housing Dataset, which was sourced from the Zillow Research Page. This dataset provides comprehensive information about housing prices across various regions, making it ideal for our analysis.
#
# To get a better understanding of our dataset, let's start by loading it and taking a look at a preview of the data. This will help us see how the data is structured and identify any initial observations or issues that need to be addressed before we proceed with our analysis.

# %%
## Importing Libraries

# %%
#Importing the data libraries
import numpy as np
import pandas as pd
import itertools
import warnings
warnings.filterwarnings('ignore')

#importing visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#Importing modeling libraries
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib.pylab import rcParams
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import joblib

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd

class DataLoader:
    def __init__(self, file_path):
        self.file_path = file_path
    
    def load_data(self):
        try:
            df = pd.read_csv(self.file_path)
            return df
        except FileNotFoundError:
            print(f"File not found: {self.file_path}")
        except pd.errors.EmptyDataError:
            print("No data: File is empty")
        except pd.errors.ParserError:
            print("Error parsing the file")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# Usage example:
file_path = 'zillow_data.csv'
data_loader = DataLoader(file_path)
df = data_loader.load_data()

if df is not None:
    print(df.head())
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %% [markdown]
# ### Data Preparation

# %%
# preview the last five columns of the dataset
df.tail()
# Out:
#        RegionID  RegionName                 City State            Metro  \
# 14718     58333        1338             Ashfield    MA  Greenfield Town
# 14719     59107        3293            Woodstock    NH        Claremont
# 14720     75672       40404                Berea    KY         Richmond
# 14721     93733       81225  Mount Crested Butte    CO              NaN
# 14722     95851       89155             Mesquite    NV        Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [5 rows x 272 columns]

# %%
#view the column names
df.columns
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=272)

# %%
# Lets rename the regionmane to zipcode because it contains the zipcode data
df = df.rename(columns={'RegionName': 'Zipcode'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        RegionID  Zipcode                 City State              Metro  \
# 0         84654    60657              Chicago    IL            Chicago
# 1         90668    75070             McKinney    TX  Dallas-Fort Worth
# 2         91982    77494                 Katy    TX            Houston
# 3         84616    60614              Chicago    IL            Chicago
# 4         93144    79936              El Paso    TX            El Paso
# ...         ...      ...                  ...   ...                ...
# 14718     58333     1338             Ashfield    MA    Greenfield Town
# 14719     59107     3293            Woodstock    NH          Claremont
# 14720     75672    40404                Berea    KY           Richmond
# 14721     93733    81225  Mount Crested Butte    CO                NaN
# 14722     95851    89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# 2         Harris         3  210400.0  212200.0  212200.0  ...   321000
# 3           Cook         4  498100.0  500900.0  503100.0  ...  1289800
# 4        El Paso         5   77300.0   77300.0   77300.0  ...   119100
# ...          ...       ...       ...       ...       ...  ...      ...
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0      1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1       310000   312500   314100   315000   316600   318100   319600   321100
# 2       320600   320200   320400   320800   321200   321200   323000   326900
# 3      1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4       119400   120000   120300   120300   120300   120300   120500   121000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 0      1030600
# 1       321800
# 2       329900
# 3      1307000
# 4       121500
# ...        ...
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [14723 rows x 272 columns]>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Validity

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
df.isna().sum()
# Out:
# RegionID       0
# Zipcode        0
# City           0
# State          0
# Metro       1043
#             ...
# 2017-12        0
# 2018-01        0
# 2018-02        0
# 2018-03        0
# 2018-04        0
# Length: 272, dtype: int64

# %%
# Remove rows with missing values (NaN) 
df.dropna(inplace = True)

# %%
# Drop rows where 'Metro' is still null
df_cleaned = df.dropna(subset=['Metro'])

# Display the cleaned DataFrame to verify
print(df_cleaned)
# Out:
#        RegionID  Zipcode          City State              Metro CountyName  \
# 0         84654    60657       Chicago    IL            Chicago       Cook
# 1         90668    75070      McKinney    TX  Dallas-Fort Worth     Collin
# 2         91982    77494          Katy    TX            Houston     Harris
# 3         84616    60614       Chicago    IL            Chicago       Cook
# 4         93144    79936       El Paso    TX            El Paso    El Paso
# ...         ...      ...           ...   ...                ...        ...
# 14716     99032    97028  Rhododendron    OR           Portland  Clackamas
# 14718     58333     1338      Ashfield    MA    Greenfield Town   Franklin
# 14719     59107     3293     Woodstock    NH          Claremont    Grafton
# 14720     75672    40404         Berea    KY           Richmond    Madison
# 14722     95851    89155      Mesquite    NV          Las Vegas      Clark
#
#        SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0             1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1             2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2             3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3             4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4             5   77300.0   77300.0   77300.0  ...   119100   119400   120000
# ...         ...       ...       ...       ...  ...      ...      ...      ...
# 14716     14717  136200.0  136600.0  136800.0  ...   332600   332900   335600
# 14718     14719   94600.0   94300.0   94000.0  ...   216800   217700   218600
# 14719     14720   92700.0   92500.0   92400.0  ...   202100   208400   212200
# 14720     14721   57100.0   57300.0   57500.0  ...   121800   122800   124600
# 14722     14723  176400.0  176300.0  176100.0  ...   333800   336400   339700
#
#        2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0      1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1       314100   315000   316600   318100   319600   321100   321800
# 2       320400   320800   321200   321200   323000   326900   329900
# 3      1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4       120300   120300   120300   120300   120500   121000   121500
# ...        ...      ...      ...      ...      ...      ...      ...
# 14716   338900   340500   341000   342300   345000   348000   349300
# 14718   218500   218100   216400   213100   209800   209200   209300
# 14719   215200   214300   213100   213700   218300   222700   225800
# 14720   126700   128800   130600   131700   132500   133000   133400
# 14722   343800   346800   348900   350400   353000   356000   357200
#
# [12895 rows x 272 columns]

# %%
df.isna().sum()
# Out:
# RegionID    0
# Zipcode     0
# City        0
# State       0
# Metro       0
#            ..
# 2017-12     0
# 2018-01     0
# 2018-02     0
# 2018-03     0
# 2018-04     0
# Length: 272, dtype: int64

# %% [markdown]
# Lets add a column on Return on investment (ROI)

# %%
#filter Zipcode
# Recalculate the number of years between the earliest and latest date
years_difference = (2018 - 1996) + (4/12)

# Calculate the Annualized ROI for each RegionName
df['Annualized_ROI'] = ((df['2018-04'] / df['1996-04'])**(1/years_difference) - 1) * 100
#annualized_roi_df = df[['RegionName', 'City', 'State', 'Annualized_ROI']]

# Sort the DataFrame based on Annualized_ROI in descending order
sorted_annualized_roi_df = df.sort_values(by='Annualized_ROI', ascending=False)

#Reveal the top 5 Regional names in terms of zipcode
sorted_annualized_roi_df.head(5)
# Out:
#       RegionID  Zipcode         City State     Metro CountyName  SizeRank  \
# 117      62022    11211     New York    NY  New York      Kings       118
# 1155     62033    11222     New York    NY  New York      Kings      1156
# 475      62027    11216     New York    NY  New York      Kings       476
# 191      60639     7302  Jersey City    NJ  New York     Hudson       192
# 106      62026    11215     New York    NY  New York      Kings       107
#
#        1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 117   133200.0  132900.0  132500.0  ...  1406400  1424700  1435300  1440500
# 1155  149200.0  148400.0  147500.0  ...  1623800  1638700  1640400  1644100
# 475   146100.0  146600.0  147200.0  ...  1506100  1553100  1567700  1559700
# 191   137200.0  137800.0  138500.0  ...  1372300  1411000  1435900  1446300
# 106   225700.0  227500.0  229400.0  ...  2201100  2244400  2266100  2275800
#
#       2017-12  2018-01  2018-02  2018-03  2018-04  Annualized_ROI
# 117   1463100  1496100  1531100  1581900  1623700       11.847669
# 1155  1651200  1661800  1672800  1694000  1721100       11.571663
# 475   1545700  1540200  1553600  1578400  1598700       11.308317
# 191   1447800  1454900  1453900  1439500  1427300       11.056640
# 106   2287100  2288900  2265300  2244900  2243900       10.831426
#
# [5 rows x 273 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df=sorted_annualized_roi_df
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    date_columns = []
    for col in df.columns[1:]:  # Skip the first column assuming it's 'RegionName'
        try:
            pd.to_datetime(col, format='%Y-%m')
            date_columns.append(col)
        except ValueError:
            continue
    return date_columns

# %%
# Identify columns that can be converted to datetime
date_columns = get_datetimes(df)
print("Date Columns:", date_columns)
# Out:
# Date Columns: ['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09', '1996-10', '1996-11', '1996-12', '1997-01', '1997-02', '1997-03', '1997-04', '1997-05', '1997-06', '1997-07', '1997-08', '1997-09', '1997-10', '1997-11', '1997-12', '1998-01', '1998-02', '1998-03', '1998-04', '1998-05', '1998-06', '1998-07', '1998-08', '1998-09', '1998-10', '1998-11', '1998-12', '1999-01', '1999-02', '1999-03', '1999-04', '1999-05', '1999-06', '1999-07', '1999-08', '1999-09', '1999-10', '1999-11', '1999-12', '2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06', '2000-07', '2000-08', '2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02', '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08', '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02', '2002-03', '2002-04', '2002-05', '2002-06', '2002-07', '2002-08', '2002-09', '2002-10', '2002-11', '2002-12', '2003-01', '2003-02', '2003-03', '2003-04', '2003-05', '2003-06', '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12', '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06', '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12', '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06', '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12', '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06', '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12', '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06', '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12', '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06', '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12', '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06', '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12', '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04']

# %%
print("Number of Date Columns:", len(date_columns))
# Out:
# Number of Date Columns: 265

# %%
# Convert wide format to long format
df_long = pd.melt(df, id_vars=['RegionID', 'Zipcode', 'City', 'State', 'Metro', 'CountyName', 'SizeRank','Annualized_ROI'],
                  var_name='Date', value_name='Price')

# Display the first few rows of the long format dataframe
df_long.head()
# Out:
#    RegionID  Zipcode         City State     Metro CountyName  SizeRank  \
# 0     62022    11211     New York    NY  New York      Kings       118
# 1     62033    11222     New York    NY  New York      Kings      1156
# 2     62027    11216     New York    NY  New York      Kings       476
# 3     60639     7302  Jersey City    NJ  New York     Hudson       192
# 4     62026    11215     New York    NY  New York      Kings       107
#
#    Annualized_ROI     Date     Price
# 0       11.847669  1996-04  133200.0
# 1       11.571663  1996-04  149200.0
# 2       11.308317  1996-04  146100.0
# 3       11.056640  1996-04  137200.0
# 4       10.831426  1996-04  225700.0

# %%
df_long.shape
# Out:
# (3417175, 10)

# %%
# Check for any missing values on the long format
df_long.isnull().sum()
# Out:
# RegionID          0
# Zipcode           0
# City              0
# State             0
# Metro             0
# CountyName        0
# SizeRank          0
# Annualized_ROI    0
# Date              0
# Price             0
# dtype: int64

# %%
# Set the date column as the index
df_long.set_index('Date', inplace=True)

# %% [markdown]
# Lets create a boxplot to visually inspect and identify potential outliers in dataset

# %%
#Checking for outliers
def check_outliers(df, columns):
    for column in columns:
        # Calculate IQR (Interquartile Range)
        iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
        
        # Define lower and upper thresholds
        lower_threshold = df[column].quantile(0.25) - 1.5 * iqr
        upper_threshold = df[column].quantile(0.75) + 1.5 * iqr
        
# Find outliers
        outliers = df[(df[column] < lower_threshold) | (df[column] > upper_threshold)]

        # Print the count of outliers
        print(f"{column}\nNumber of outliers: {len(outliers)}\n")

#Call the function
columns_to_check = df.select_dtypes(include = ['number'])
check_outliers(df, columns_to_check)
# Out:
# RegionID
# Number of outliers: 101
#
# Zipcode
# Number of outliers: 0
#
# SizeRank
# Number of outliers: 0
#
# 1996-04
# Number of outliers: 655
#
# 1996-05
# Number of outliers: 655
#
# 1996-06
# Number of outliers: 658
#
# 1996-07
# Number of outliers: 661
#
# 1996-08
# Number of outliers: 664
#
# 1996-09
# Number of outliers: 665
#
# 1996-10
# Number of outliers: 669
#
# 1996-11
# Number of outliers: 669
#
# 1996-12
# Number of outliers: 666
#
# 1997-01
# Number of outliers: 667
#
# 1997-02
# Number of outliers: 672
#
# 1997-03
# Number of outliers: 676
#
# 1997-04
# Number of outliers: 688
#
# 1997-05
# Number of outliers: 686
#
# 1997-06
# Number of outliers: 689
#
# 1997-07
# Number of outliers: 691
#
# 1997-08
# Number of outliers: 687
#
# 1997-09
# Number of outliers: 690
#
# 1997-10
# Number of outliers: 699
#
# 1997-11
# Number of outliers: 719
#
# 1997-12
# Number of outliers: 723
#
# 1998-01
# Number of outliers: 726
#
# 1998-02
# Number of outliers: 726
#
# 1998-03
# Number of outliers: 732
#
# 1998-04
# Number of outliers: 737
#
# 1998-05
# Number of outliers: 738
#
# 1998-06
# Number of outliers: 739
#
# 1998-07
# Number of outliers: 742
#
# 1998-08
# Number of outliers: 746
#
# 1998-09
# Number of outliers: 757
#
# 1998-10
# Number of outliers: 762
#
# 1998-11
# Number of outliers: 764
#
# 1998-12
# Number of outliers: 769
#
# 1999-01
# Number of outliers: 774
#
# 1999-02
# Number of outliers: 784
#
# 1999-03
# Number of outliers: 786
#
# 1999-04
# Number of outliers: 794
#
# 1999-05
# Number of outliers: 804
#
# 1999-06
# Number of outliers: 812
#
# 1999-07
# Number of outliers: 815
#
# 1999-08
# Number of outliers: 820
#
# 1999-09
# Number of outliers: 825
#
# 1999-10
# Number of outliers: 834
#
# 1999-11
# Number of outliers: 843
#
# 1999-12
# Number of outliers: 850
#
# 2000-01
# Number of outliers: 864
#
# 2000-02
# Number of outliers: 868
#
# 2000-03
# Number of outliers: 870
#
# 2000-04
# Number of outliers: 879
#
# 2000-05
# Number of outliers: 889
#
# 2000-06
# Number of outliers: 893
#
# 2000-07
# Number of outliers: 894
#
# 2000-08
# Number of outliers: 901
#
# 2000-09
# Number of outliers: 907
#
# 2000-10
# Number of outliers: 907
#
# 2000-11
# Number of outliers: 913
#
# 2000-12
# Number of outliers: 913
#
# 2001-01
# Number of outliers: 914
#
# 2001-02
# Number of outliers: 924
#
# 2001-03
# Number of outliers: 921
#
# 2001-04
# Number of outliers: 921
#
# 2001-05
# Number of outliers: 924
#
# 2001-06
# Number of outliers: 928
#
# 2001-07
# Number of outliers: 924
#
# 2001-08
# Number of outliers: 915
#
# 2001-09
# Number of outliers: 915
#
# 2001-10
# Number of outliers: 909
#
# 2001-11
# Number of outliers: 908
#
# 2001-12
# Number of outliers: 910
#
# 2002-01
# Number of outliers: 908
#
# 2002-02
# Number of outliers: 903
#
# 2002-03
# Number of outliers: 906
#
# 2002-04
# Number of outliers: 904
#
# 2002-05
# Number of outliers: 897
#
# 2002-06
# Number of outliers: 887
#
# 2002-07
# Number of outliers: 881
#
# 2002-08
# Number of outliers: 885
#
# 2002-09
# Number of outliers: 886
#
# 2002-10
# Number of outliers: 882
#
# 2002-11
# Number of outliers: 873
#
# 2002-12
# Number of outliers: 868
#
# 2003-01
# Number of outliers: 863
#
# 2003-02
# Number of outliers: 862
#
# 2003-03
# Number of outliers: 860
#
# 2003-04
# Number of outliers: 862
#
# 2003-05
# Number of outliers: 861
#
# 2003-06
# Number of outliers: 867
#
# 2003-07
# Number of outliers: 868
#
# 2003-08
# Number of outliers: 862
#
# 2003-09
# Number of outliers: 859
#
# 2003-10
# Number of outliers: 862
#
# 2003-11
# Number of outliers: 858
#
# 2003-12
# Number of outliers: 856
#
# 2004-01
# Number of outliers: 853
#
# 2004-02
# Number of outliers: 855
#
# 2004-03
# Number of outliers: 857
#
# 2004-04
# Number of outliers: 870
#
# 2004-05
# Number of outliers: 876
#
# 2004-06
# Number of outliers: 879
#
# 2004-07
# Number of outliers: 888
#
# 2004-08
# Number of outliers: 888
#
# 2004-09
# Number of outliers: 891
#
# 2004-10
# Number of outliers: 897
#
# 2004-11
# Number of outliers: 896
#
# 2004-12
# Number of outliers: 892
#
# 2005-01
# Number of outliers: 896
#
# 2005-02
# Number of outliers: 898
#
# 2005-03
# Number of outliers: 892
#
# 2005-04
# Number of outliers: 891
#
# 2005-05
# Number of outliers: 882
#
# 2005-06
# Number of outliers: 873
#
# 2005-07
# Number of outliers: 869
#
# 2005-08
# Number of outliers: 858
#
# 2005-09
# Number of outliers: 848
#
# 2005-10
# Number of outliers: 843
#
# 2005-11
# Number of outliers: 839
#
# 2005-12
# Number of outliers: 836
#
# 2006-01
# Number of outliers: 832
#
# 2006-02
# Number of outliers: 816
#
# 2006-03
# Number of outliers: 803
#
# 2006-04
# Number of outliers: 796
#
# 2006-05
# Number of outliers: 791
#
# 2006-06
# Number of outliers: 793
#
# 2006-07
# Number of outliers: 793
#
# 2006-08
# Number of outliers: 794
#
# 2006-09
# Number of outliers: 787
#
# 2006-10
# Number of outliers: 788
#
# 2006-11
# Number of outliers: 790
#
# 2006-12
# Number of outliers: 787
#
# 2007-01
# Number of outliers: 789
#
# 2007-02
# Number of outliers: 795
#
# 2007-03
# Number of outliers: 788
#
# 2007-04
# Number of outliers: 789
#
# 2007-05
# Number of outliers: 789
#
# 2007-06
# Number of outliers: 795
#
# 2007-07
# Number of outliers: 791
#
# 2007-08
# Number of outliers: 789
#
# 2007-09
# Number of outliers: 788
#
# 2007-10
# Number of outliers: 792
#
# 2007-11
# Number of outliers: 792
#
# 2007-12
# Number of outliers: 791
#
# 2008-01
# Number of outliers: 787
#
# 2008-02
# Number of outliers: 794
#
# 2008-03
# Number of outliers: 800
#
# 2008-04
# Number of outliers: 806
#
# 2008-05
# Number of outliers: 816
#
# 2008-06
# Number of outliers: 816
#
# 2008-07
# Number of outliers: 823
#
# 2008-08
# Number of outliers: 829
#
# 2008-09
# Number of outliers: 834
#
# 2008-10
# Number of outliers: 835
#
# 2008-11
# Number of outliers: 846
#
# 2008-12
# Number of outliers: 855
#
# 2009-01
# Number of outliers: 864
#
# 2009-02
# Number of outliers: 878
#
# 2009-03
# Number of outliers: 877
#
# 2009-04
# Number of outliers: 881
#
# 2009-05
# Number of outliers: 884
#
# 2009-06
# Number of outliers: 892
#
# 2009-07
# Number of outliers: 908
#
# 2009-08
# Number of outliers: 910
#
# 2009-09
# Number of outliers: 915
#
# 2009-10
# Number of outliers: 917
#
# 2009-11
# Number of outliers: 913
#
# 2009-12
# Number of outliers: 928
#
# 2010-01
# Number of outliers: 932
#
# 2010-02
# Number of outliers: 935
#
# 2010-03
# Number of outliers: 927
#
# 2010-04
# Number of outliers: 936
#
# 2010-05
# Number of outliers: 934
#
# 2010-06
# Number of outliers: 933
#
# 2010-07
# Number of outliers: 927
#
# 2010-08
# Number of outliers: 932
#
# 2010-09
# Number of outliers: 930
#
# 2010-10
# Number of outliers: 936
#
# 2010-11
# Number of outliers: 943
#
# 2010-12
# Number of outliers: 947
#
# 2011-01
# Number of outliers: 952
#
# 2011-02
# Number of outliers: 951
#
# 2011-03
# Number of outliers: 955
#
# 2011-04
# Number of outliers: 954
#
# 2011-05
# Number of outliers: 955
#
# 2011-06
# Number of outliers: 954
#
# 2011-07
# Number of outliers: 957
#
# 2011-08
# Number of outliers: 955
#
# 2011-09
# Number of outliers: 959
#
# 2011-10
# Number of outliers: 960
#
# 2011-11
# Number of outliers: 968
#
# 2011-12
# Number of outliers: 962
#
# 2012-01
# Number of outliers: 966
#
# 2012-02
# Number of outliers: 965
#
# 2012-03
# Number of outliers: 970
#
# 2012-04
# Number of outliers: 973
#
# 2012-05
# Number of outliers: 975
#
# 2012-06
# Number of outliers: 983
#
# 2012-07
# Number of outliers: 983
#
# 2012-08
# Number of outliers: 986
#
# 2012-09
# Number of outliers: 991
#
# 2012-10
# Number of outliers: 990
#
# 2012-11
# Number of outliers: 993
#
# 2012-12
# Number of outliers: 992
#
# 2013-01
# Number of outliers: 998
#
# 2013-02
# Number of outliers: 1009
#
# 2013-03
# Number of outliers: 1017
#
# 2013-04
# Number of outliers: 1024
#
# 2013-05
# Number of outliers: 1027
#
# 2013-06
# Number of outliers: 1031
#
# 2013-07
# Number of outliers: 1031
#
# 2013-08
# Number of outliers: 1027
#
# 2013-09
# Number of outliers: 1025
#
# 2013-10
# Number of outliers: 1023
#
# 2013-11
# Number of outliers: 1024
#
# 2013-12
# Number of outliers: 1026
#
# 2014-01
# Number of outliers: 1029
#
# 2014-02
# Number of outliers: 1028
#
# 2014-03
# Number of outliers: 1031
#
# 2014-04
# Number of outliers: 1030
#
# 2014-05
# Number of outliers: 1028
#
# 2014-06
# Number of outliers: 1033
#
# 2014-07
# Number of outliers: 1035
#
# 2014-08
# Number of outliers: 1042
#
# 2014-09
# Number of outliers: 1045
#
# 2014-10
# Number of outliers: 1049
#
# 2014-11
# Number of outliers: 1042
#
# 2014-12
# Number of outliers: 1043
#
# 2015-01
# Number of outliers: 1042
#
# 2015-02
# Number of outliers: 1043
#
# 2015-03
# Number of outliers: 1042
#
# 2015-04
# Number of outliers: 1039
#
# 2015-05
# Number of outliers: 1037
#
# 2015-06
# Number of outliers: 1044
#
# 2015-07
# Number of outliers: 1040
#
# 2015-08
# Number of outliers: 1032
#
# 2015-09
# Number of outliers: 1036
#
# 2015-10
# Number of outliers: 1036
#
# 2015-11
# Number of outliers: 1031
#
# 2015-12
# Number of outliers: 1028
#
# 2016-01
# Number of outliers: 1028
#
# 2016-02
# Number of outliers: 1021
#
# 2016-03
# Number of outliers: 1021
#
# 2016-04
# Number of outliers: 1019
#
# 2016-05
# Number of outliers: 1020
#
# 2016-06
# Number of outliers: 1016
#
# 2016-07
# Number of outliers: 1003
#
# 2016-08
# Number of outliers: 1004
#
# 2016-09
# Number of outliers: 996
#
# 2016-10
# Number of outliers: 993
#
# 2016-11
# Number of outliers: 1000
#
# 2016-12
# Number of outliers: 996
#
# 2017-01
# Number of outliers: 1004
#
# 2017-02
# Number of outliers: 1003
#
# 2017-03
# Number of outliers: 997
#
# 2017-04
# Number of outliers: 994
#
# 2017-05
# Number of outliers: 1000
#
# 2017-06
# Number of outliers: 999
#
# 2017-07
# Number of outliers: 1005
#
# 2017-08
# Number of outliers: 1013
#
# 2017-09
# Number of outliers: 1018
#
# 2017-10
# Number of outliers: 1015
#
# 2017-11
# Number of outliers: 1010
#
# 2017-12
# Number of outliers: 1008
#
# 2018-01
# Number of outliers: 1007
#
# 2018-02
# Number of outliers: 1005
#
# 2018-03
# Number of outliers: 1005
#
# 2018-04
# Number of outliers: 1003
#
# Annualized_ROI
# Number of outliers: 403

# %%
# Plotting the boxplot to visualize outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_long['Price'])
plt.title('Boxplot of Real Estate Prices (with outliers)')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# Based on the presence of whiskers in the box plot, we can confirm that there are outliers in the data set. While the outliers might not be extremely far from the rest of the data, their existence indicates that some real estate prices deviate considerably from the middle 50% range.
#
# The whiskers in the box plot extend beyond the box, indicating the presence of data points outside the interquartile range.
#
# The boxplots indicates there are outliers present but we cant drop them because they are actual events recorded

# %% [markdown]
# The next step is to investigate Outliers to Identify and investigate these outliers to understand the characteristics of these high-priced properties. Determine if they should be included or excluded from further analysis based on their impact on the results.

# %%
#Checking for Outliers using IQR

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_long['Price'].quantile(0.25)
Q3 = df_long['Price'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define the outlier cutoff
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df_long[(df_long['Price'] < lower_bound) | (df_long['Price'] > upper_bound)]

# Print the number of outliers and some examples
print(f"Number of outliers: {len(outliers)}")
outliers.head()
# Out:
# Number of outliers: 258901
#          RegionID  Zipcode            City State  \
# Date
# 1996-04     97691    94301       Palo Alto    CA
# 1996-04     72442    33139     Miami Beach    FL
# 1996-04     97571    94117   San Francisco    CA
# 1996-04     96050    90069  West Hollywood    CA
# 1996-04     96086    90210   Beverly Hills    CA
#
#                                   Metro     CountyName  SizeRank  \
# Date
# 1996-04                        San Jose    Santa Clara      5739
# 1996-04           Miami-Fort Lauderdale     Miami-Dade        85
# 1996-04                   San Francisco  San Francisco       897
# 1996-04  Los Angeles-Long Beach-Anaheim    Los Angeles      1897
# 1996-04  Los Angeles-Long Beach-Anaheim    Los Angeles      4817
#
#          Annualized_ROI      Price
# Date
# 1996-04        8.956091   709500.0
# 1996-04        8.408513   480200.0
# 1996-04        8.346852   481000.0
# 1996-04        8.283683   533600.0
# 1996-04        8.244182  1015400.0

# %% [markdown]
# ## EDA
# Next, we will performing Exploratory Data Analysis (EDA) to uncover patterns, trends, and relationships within the dataset, using:
#
# Univeriate analysis
#
# Bivariate analysis

# %% [markdown]
# The following visualizations present key insights into the most frequent entries across counties, states, and cities in the dataset. Using horizontal and vertical bar charts, these graphs are designed to reveal the distribution and prominence of different geographical areas, providing a clear comparative view of the top 10 entries in each category.

# %%
# Create a new figure with dimensions 15x8 inches
plt.figure(figsize=(15, 8))

# Plot a vertical bar chart showing the top 10 most frequent states
df_long['State'].value_counts().nlargest(10).plot(kind="bar", color='skyblue')

# Label the x-axis as "Count"
plt.xlabel("Count", fontsize=15)

# Label the y-axis as "US States"
plt.ylabel("US States", fontsize=15)

# Set x-axis tick labels to be horizontal
plt.xticks(rotation=0)

# Set the plot title as "Most Popular States"
plt.title("Most Popular States", fontsize=20)

# Add a grid to the y-axis for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %%
# Create a new figure with dimensions 15x8 inches
plt.figure(figsize=(15, 8))

# Plot a vertical bar chart showing the top 10 most frequent cities
df_long['City'].value_counts().nlargest(10).plot(kind="bar", color='skyblue')

# Label the x-axis as "US Cities"
plt.xlabel("US Cities", fontsize=15)

# Label the y-axis as "Count"
plt.ylabel("Count", fontsize=15)

# Rotate x-axis labels by 45 degrees for better readability and align them to the right
plt.xticks(rotation=45, ha='right')

# Set the plot title as "Most Popular Cities"
plt.title("Most Popular Cities", fontsize=20)

# Add a grid to the y-axis for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust the layout to prevent label cutoff
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# The horizontal bar chart shows the top 10 counties with the highest entry counts, while the vertical bar charts display the top 10 states and cities by frequency. These charts reveal which counties, states, and cities are most commonly represented in the dataset, with labels and grid lines added for clarity and readability.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Price Over Time

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data=df_long, x='Date', y='Price')
plt.title('Price Over Time')
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# The graph shows a time series line plot with a shaded area representing uncertainty or variability. It displays a rising trend followed by a peak, a decline, a slight dip, and then another rise, indicating cyclical behavior or responses to certain conditions. The shaded area suggests the level of confidence or variability in the data over time.

# %% [markdown]
# ### Rolling Average Prices

# %%
df_long['Rolling_Avg'] = df_long['Price'].rolling(window=6).mean()
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_long, x='Date', y='Price', label='Monthly Prices', color='blue')
sns.lineplot(data=df_long, x='Date', y='Rolling_Avg', label='6-Month Rolling Average', color='red')
plt.title('Home Prices and 6-Month Rolling Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows two lines representing different data series over time:
#
# 1. **Monthly Prices (Blue Line)**: This line represents the actual data points for prices on a monthly basis. The fluctuations and trends in this line reflect the monthly changes in prices.
#
# 2. **6-Month Rolling Average (Red Line)**: This line smooths the monthly prices by averaging them over a six-month period, providing a clearer view of longer-term trends by reducing short-term volatility.
#
# The shaded area around each line likely indicates the variability or confidence intervals for those data points. The rolling average helps to highlight underlying trends by filtering out noise from the monthly data. Overall, the graph demonstrates how prices have fluctuated over time, with the rolling average providing a more stable representation of these changes.

# %% [markdown]
# ### Mean Home Value by Metro

# %%
# Grouping the data by 'Metro' and calculating the mean 'Price' for each metro area
metro_mean_values = df_long.groupby('Metro')['Price'].mean()

# Sorting the metro areas by mean price in descending order and selecting the top 10
top_10_metros = metro_mean_values.sort_values(ascending=False).head(10)

# Converting the Series to a DataFrame and resetting the index for better handling
top_10_metros_df = top_10_metros.reset_index()

# Setting a smaller figure size for the plot
plt.figure(figsize=(8, 5))

# Creating a bar graph to visualize the mean home values by metro area, with bars colored orange
plt.bar(top_10_metros_df['Metro'], top_10_metros_df['Price'], color='orange')

# Adding annotations for each bar for clarity
for i in range(len(top_10_metros_df)):
    plt.text(i, top_10_metros_df['Price'][i], 
             f"${top_10_metros_df['Price'][i]:,.0f}", 
             ha='center', va='bottom', fontsize=9)

# Adding the title and labels
plt.title('Mean Home Value by Metro')
plt.xlabel('Metro')
plt.ylabel('Mean Value in Dollars ($)')

# Rotating the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Displaying the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # Adjust layout to prevent label cutoff
plt.show()

# %% [markdown]
# Thebar chart shows the top 10 metropolitan areas with the highest mean home values. It helps in comparing the average home values across different metro areas and identify where the highest values are concentrated.

# %% [markdown]
# ### Mean Home Value by County

# %%
# Calculate mean home values by county and get the top 10
county_mean_values = df_long.groupby('CountyName')['Price'].mean()
top_10_counties = county_mean_values.sort_values(ascending=False).head(10)

# Convert index and values to lists
counties_list = top_10_counties.index.tolist()
values_list = top_10_counties.values.tolist()

# Plotting the mean home values by county using a line plot
plt.figure(figsize=(12, 7))
plt.plot(counties_list, values_list, marker='o', color='darkgreen')

# Setting the title and labels for the plot
plt.title('Mean Home Value by County')
plt.xlabel('County Name')
plt.ylabel('Mean Value in Dollars ($)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Display the plot
plt.show()

# %% [markdown]
# - **Decreasing Trend**: The chart shows a consistently decreasing trend, suggesting that whatever is being measured is reducing over time or across categories.
# - **Points of Interest**: Certain points might stand out if the rate of decrease is more pronounced, or if there is a leveling off at the end.

# %% [markdown]
# ### Top 10 ZIP Codes by Mean ROI

# %%
# Plotting the distribution of Annualized ROI values across all ZIP codes
plt.figure(figsize=(12, 7))

# Create histogram
plt.hist(df_long['Annualized_ROI'], bins=30, color='blue', edgecolor='black')

# Setting the title and labels for the plot
plt.title('Distribution of Annualized ROI')
plt.xlabel('Annualized ROI')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
# Calculate mean ROI by ZIP code and get the top 10
zipcode_mean_roi = df_long.groupby('Zipcode')['Annualized_ROI'].mean()
top_10_zipcodes = zipcode_mean_roi.sort_values(ascending=False).head(10).index

# Filter the original DataFrame to include only these top 10 ZIP codes
filtered_df = df_long[df_long['Zipcode'].isin(top_10_zipcodes)]

# Plotting the distribution of Annualized ROI for top 10 ZIP codes
plt.figure(figsize=(12, 7))

# Create histogram
plt.hist(filtered_df['Annualized_ROI'], bins=30, color='purple', edgecolor='black')

# Setting the title and labels for the plot
plt.title('Distribution of Annualized ROI for Top 10 ZIP Codes')
plt.xlabel('Annualized ROI')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# This bar chart provides a visual comparison of values across multiple categories, with the height of each bar indicating the value associated with each category. Without specific labels for the axes or a title, it's challenging to provide a precise interpretation. Additional context or labels for the axes would allow for a more detailed and accurate analysis.

# %% [markdown]
# ### Distribution of House Prices by Zipcode

# %%
# Calculate average house price by ZIP code
zipcode_mean_price = df_long.groupby('Zipcode')['Price'].mean().sort_index()

# Convert index and values to lists
zipcodes_list = zipcode_mean_price.index.tolist()
mean_prices_list = zipcode_mean_price.values.tolist()

# Plotting the average house prices by ZIP code using a line plot
plt.figure(figsize=(15, 6))
plt.plot(zipcodes_list, mean_prices_list, marker='o', color='darkgreen')

# Setting the title and labels for the plot
plt.title('Average House Prices by Zipcode')
plt.xlabel('Zipcode')
plt.ylabel('Average Price')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Display the plot
plt.show()

# %% [markdown]
# **Interpretation:**
#
# 1. **High-Density Clusters:**
#    - The scatter plot reveals several regions along the X-axis (average price) where data points are densely clustered. This clustering suggests that multiple ZIP codes have similar average prices.
#    - Notably, there are clusters with lower average prices and fewer clusters with higher average prices, indicating variations in price density across different ZIP codes.
#
# 2. **Peaks:**
#    - The plot features distinct vertical lines (peaks) corresponding to specific average prices shared by multiple ZIP codes. These peaks highlight average prices that are more common among various ZIP codes.
#    - For example, certain average prices, such as $300,000, appear frequently across several ZIP codes, indicating a common price point in the market.
#
# 3. **Sparse Areas:**
#    - There are regions on the plot with few or no data points, suggesting that certain average prices are less common among the ZIP codes.
#    - This sparsity might imply that either these price ranges are less prevalent in the housing market or that specific ZIP codes have unique pricing structures.
#
# 4. **Price Distribution:**
#    - The distribution of prices varies significantly across ZIP codes. Higher peaks indicate that certain average prices are more prevalent, while other prices are less common.
#    - This variation in distribution provides insights into the pricing trends across different ZIP codes.
#
# **Hypothetical Examples:**
#
# - **Real Estate Analysis:**
#   - This scatter plot can assist in understanding which ZIP codes have similar housing markets. For instance, clusters of similar average prices can reveal areas with comparable property values.
#   - The peaks can identify standard pricing bands within the market, suggesting common price points among multiple ZIP codes.

# %% [markdown]
# ## Bivariate Analysis
# ### Price vs. SizeRank

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_long, x='SizeRank', y='Price')
plt.xlabel('SizeRank')
plt.ylabel('Price')
plt.show()

# %%
df_long_sample = df_long.sample(2000)  # Adjust the number as needed
sns.lineplot(data=df_long_sample, x='SizeRank', y='Price')
plt.show()

# %% [markdown]
# **Distribution and Trends:** The plot shows a large number of data points with prices fluctuating across different size ranks. There are noticeable peaks in certain areas, which might indicate properties with significantly higher prices at specific size ranks.
#
# **Variability:** The plot demonstrates high variability in property prices, suggesting that factors other than size significantly influence property prices. This could include location, property features, market conditions, and more.

# %% [markdown]
# ### SizeRank Over Time

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_long, x='Date', y='SizeRank')
plt.xlabel('Date')
plt.ylabel('SizeRank')
plt.show()

# %% [markdown]
# This plot shows how SizeRank changes over time. It helps in understanding if the popularity or ranking of ZIP codes changes and how that might relate to home prices or other factors over time.

# %%
# Ensure 'SizeRank' column is numeric
df_long['SizeRank'] = pd.to_numeric(df_long['SizeRank'], errors='coerce')

# Drop any rows where 'SizeRank' could not be converted to numeric (NaN values)
df_long = df_long.dropna(subset=['SizeRank'])

# Histogram of SizeRank Distribution
plt.figure(figsize=(12, 6))
sns.histplot(df_long['SizeRank'], bins=30)
plt.xlabel('SizeRank')
plt.ylabel('Frequency')
plt.title('Distribution of SizeRank')
plt.show()

# %% [markdown]
# **Distribution Shape:** The histogram shows a decreasing trend from left to right, with the highest frequency on the left side. This suggests that lower `SizeRank` values (which might indicate smaller or less desirable properties, depending on the dataset’s context) are more common in the dataset.
#
# **Height of Bars:** Each bar’s height corresponds to the number of observations (or properties) that fall into each `SizeRank` bin. Taller bars indicate more properties with similar `SizeRank` values.
#
# **KDE Curve:** The histogram appears to have an overlaid Kernel Density Estimate (KDE) curve, which smooths the histogram into a continuous probability density function. This curve helps to visualize the distribution's general shape and density.
#
# ### Summary
# The histogram indicates a right-skewed distribution, where most properties have lower `SizeRank` values, and fewer properties have higher `SizeRank` values. This could imply that smaller or less desirable properties are more prevalent in the dataset.

# %% [markdown]
#  # Stationarity Check and Transformation

# %% [markdown]
# We shall first check for stationarity

# %%
#A function to check for stationary
from statsmodels.tsa.stattools import adfuller

def check_stationarity(series):
    result = adfuller(series)
    print("P value:", result[1])

    if result[1]>0.05:
        print("Is non stationary")
    else:
        print("Is stationary")

# %%
#Using the function to check for stationarity
check_stationarity(df_long_sample["Price"])
# Out:
# P value: 0.0
# Is stationary

# %% [markdown]
# Our dataset is stationary

# %%
#Getting P,Q,& D
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#Plot partial autocorrelation (P)
plt.figure(figsize=(15, 5))
plot_pacf(df_long["Price"],lags=20)
plt.xlabel("Lags")
plt.ylabel("Partial Autocorrelation")
plt.title("Partial Autocorrelation Function (PACF) for price")
plt.show()

# %%
#Plot autocorrelation plot(Q)
plt.figure(figsize=(15, 5))
plot_acf(df_long_sample["Price"],lags=20);
plt.xlabel("Lags")
plt.ylabel("Autocorrelation")
plt.title("Autocorrelation Function (ACF) for price")
plt.show()

# %% [markdown]
# # MODELLING

# %% [markdown]
# # Prophet model.

# %% [markdown]
# Prophet is a time series forecasting library from Meta. To be able to build a model with Prophet we need to reset the index of our train and test datasets.

# %%
import pandas as pd

# Example DataFrames
train = pd.DataFrame({
    'Date': pd.date_range(start='2021-01-01', periods=10, freq='D'),
    'value': range(10)
})

test = pd.DataFrame({
    'Date': pd.date_range(start='2021-01-11', periods=5, freq='D'),
    'value': range(10, 15)
})

# Reset index and rename columns
train2 = train.reset_index()
train2 = train2.rename(columns={'Date': 'ds', 'value': 'y'})

test2 = test.reset_index()
test2 = test2.rename(columns={'Date': 'ds', 'value': 'y'})

print(train2)
print(test2)
# Out:
#    index         ds  y
# 0      0 2021-01-01  0
# 1      1 2021-01-02  1
# 2      2 2021-01-03  2
# 3      3 2021-01-04  3
# 4      4 2021-01-05  4
# 5      5 2021-01-06  5
# 6      6 2021-01-07  6
# 7      7 2021-01-08  7
# 8      8 2021-01-09  8
# 9      9 2021-01-10  9
#    index         ds   y
# 0      0 2021-01-11  10
# 1      1 2021-01-12  11
# 2      2 2021-01-13  12
# 3      3 2021-01-14  13
# 4      4 2021-01-15  14

# %%
#Resetting the index of the train data
train2 = train.reset_index()
train2 = train2.rename(columns={'Date': 'ds', 'value': 'y'})
test2 = test.reset_index()
test2 = test2.rename(columns={'Date': 'ds', 'value': 'y'})

# %% [markdown]
# We will now create a baseline Prophet model using default parameters.

# %%
#Prophet model with default hyperparameters
prophet_model1 = Prophet()
prophet_model1.fit(train2)
future_dates1 = prophet_model1.make_future_dataframe(periods=len(test2), freq='M') 
forecast1 = prophet_model1.predict(future_dates1)
test_predictions1 = forecast1['yhat'][-len(test2):]
metrics(test2['y'], test_predictions1)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# {'MAE': 77.20000000000002, 'RMSE': 87.48714191239765}

# %% [markdown]
# From the model above the RMSE is at 77.2 and 87.45 which are worse than our previous models. We will go ahead and conduct manual hyerparameter tuning to create a better model.

# %%
# Manual Hyperparameter tuning for the prophet model
param_grid = {
    "changepoint_prior_scale": [0.01, 0.1, 1.0],
    "seasonality_mode": ["additive", "multiplicative"],
}

# Perform manual hyperparameter tuning
best_rmse = np.inf
best_params = None

for changepoint_prior_scale in param_grid["changepoint_prior_scale"]:
    for seasonality_mode in param_grid["seasonality_mode"]:
        model = Prophet(
            changepoint_prior_scale=changepoint_prior_scale,
            seasonality_mode=seasonality_mode,
        )

        # Fit the model on the training data
        model.fit(train2)

        # Make predictions on the validation set
        future = model.make_future_dataframe(periods=len(test2))
        forecast = model.predict(future)

        # Calculate RMSE
        rmse = np.sqrt(mean_squared_error(test2["y"], forecast["yhat"][:len(test2)]))

        # Check if the current combination of hyperparameters is the best
        if rmse < best_rmse:
            best_rmse = rmse
            best_params = {
                "changepoint_prior_scale": changepoint_prior_scale,
                "seasonality_mode": seasonality_mode,
            }

print("Best Hyperparameters:", best_params)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Best Hyperparameters: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'additive'}

# %%
# Creating a Prophet model using the suggested hyperparameters
from fbprophet import Prophet

def metrics(true_values, predicted_values):
    mae = mean_absolute_error(true_values, predicted_values)
    rmse = np.sqrt(mean_squared_error(true_values, predicted_values))
    return {'MAE': mae, 'RMSE': rmse}

param_dict = {'changepoint_prior_scale': 1.0, 'seasonality_mode': 'multiplicative'}
prophet_model2 = Prophet(**param_dict)
prophet_model2.fit(train2)
future_dates = prophet_model2.make_future_dataframe(periods=len(test2), freq='M')
forecast = prophet_model2.predict(future_dates)
test_predictions2 = forecast['yhat'][-len(test2):]
metrics(test2['y'], test_predictions2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# {'MAE': 77.2, 'RMSE': 87.48714191239762}

# %% [markdown]
# The tuned model gives an RMSE of 87 and MAE of 77.2 which is the same as the first prophet model. However, it performs poorly than the ARIMA models. We will now use optuna for hyperparameter tuning and see if we can create a better model.

# %%
# Define the objective function to optimize
import optuna
import joblib
from fbprophet import Prophet


def objective(trial):
    # Create a Prophet model with suggested hyperparameters
    model = Prophet(
        changepoint_prior_scale=trial.suggest_float("changepoint_prior_scale", 0.001, 0.5),
        seasonality_mode=trial.suggest_categorical("seasonality_mode", ["additive", "multiplicative"]),
    )
    # Fit the model to the training data
    model.fit(train2)

    # Make predictions on the validation set
    future_dates = model.make_future_dataframe(periods=len(test2), freq='M')
    forecast = model.predict(future_dates)
    test_predictions = forecast['yhat'][-len(test2):]
    
    # Calculate evaluation metric (e.g., RMSE)
    rmse = np.sqrt(mean_squared_error(test2['y'], test_predictions))

    return rmse  # Minimize RMSE

# Create an Optuna study
study = optuna.create_study(direction="minimize")

# Run the optimization
study.optimize(objective, n_trials=100)  # Adjust the number of trials as needed

# Get the best hyperparameters
best_params = study.best_params

# Create the best model using the optimal hyperparameters
best_model = Prophet(**best_params)
# Fit the best model to the entire dataset
best_model.fit(train2)

# Predicting the values
future_dates = best_model.make_future_dataframe(periods=len(test2), freq='M')
forecast = best_model.predict(future_dates)
test_predictions3 = forecast['yhat'][-len(test2):]
metrics(test2['y'], test_predictions3)
# Out:
# [I 2024-07-28 10:15:57,862] A new study created in memory with name: no-name-426e6b52-9fb3-43ef-8749-13f4ee534669
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:02,767] Trial 0 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.3611180611902523, 'seasonality_mode': 'multiplicative'}. Best is trial 0 with value: 87.48714191239766.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:08,117] Trial 1 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.2009391239319902, 'seasonality_mode': 'additive'}. Best is trial 0 with value: 87.48714191239766.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:12,388] Trial 2 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.4838846878127089, 'seasonality_mode': 'multiplicative'}. Best is trial 2 with value: 87.48714191239765.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:16,987] Trial 3 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.024310619448336124, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:21,013] Trial 4 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.24060048566873177, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:25,287] Trial 5 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.1878611387421162, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:29,195] Trial 6 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.4567936862602153, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:33,190] Trial 7 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.3337218139229644, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:36,673] Trial 8 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.2243055055245185, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:40,089] Trial 9 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.022875526980313997, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:43,672] Trial 10 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.0027485381831152678, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:46,937] Trial 11 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.010557682435779259, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:50,445] Trial 12 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.0999685108190779, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:54,161] Trial 13 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.1091357630018035, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:16:57,661] Trial 14 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.10120205707056693, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:01,343] Trial 15 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.05654089896206106, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:05,210] Trial 16 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.13872097922732501, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:08,951] Trial 17 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.3276151228360392, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:12,342] Trial 18 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.05223997171498812, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:15,858] Trial 19 finished with value: 87.48714191239769 and parameters: {'changepoint_prior_scale': 0.17043129938261228, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:19,315] Trial 20 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.0543791365393863, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:22,869] Trial 21 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.017288424766779845, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:28,231] Trial 22 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.006398208203810915, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:32,065] Trial 23 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.05356607203992398, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:35,605] Trial 24 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.13982300031675737, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:39,246] Trial 25 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.08358888100912966, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:42,945] Trial 26 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.27456346734898174, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:46,487] Trial 27 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.003188482677640398, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:50,111] Trial 28 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.13901657707233936, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:53,927] Trial 29 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.040736649284679585, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:17:57,710] Trial 30 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.0826206239962857, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:01,101] Trial 31 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.0444533477916894, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:04,817] Trial 32 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.06430828766821005, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:08,450] Trial 33 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.02740378411435404, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:11,815] Trial 34 finished with value: 87.48714191239769 and parameters: {'changepoint_prior_scale': 0.12709041505094332, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:15,473] Trial 35 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.07596618654284223, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:19,098] Trial 36 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.17560886245176704, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:22,406] Trial 37 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.4063248301360038, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:26,138] Trial 38 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.2652541943518583, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:30,063] Trial 39 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.027840599968198536, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:33,629] Trial 40 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.20498709518230013, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:37,237] Trial 41 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.1531879792895416, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:41,002] Trial 42 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.1022731804144697, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:44,443] Trial 43 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.0031342129194337626, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:48,268] Trial 44 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.03408236464741039, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:52,017] Trial 45 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.12267606431166447, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:55,667] Trial 46 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.0772405104764512, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:18:58,874] Trial 47 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.028154125187270507, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:02,474] Trial 48 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.06205523159939753, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:05,965] Trial 49 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.10504074078241318, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:09,390] Trial 50 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.30081776578728875, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:12,814] Trial 51 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.0233857305057681, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:16,480] Trial 52 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.03710845252619998, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:20,021] Trial 53 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.0011413609553198173, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:23,587] Trial 54 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.0662516874462814, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:26,954] Trial 55 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.08649943119674144, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:30,945] Trial 56 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.019513735812922865, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:34,560] Trial 57 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.05211336063766595, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:38,185] Trial 58 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.2273526274747577, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:41,602] Trial 59 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.017943253328976477, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:45,434] Trial 60 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.47798600181220885, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:48,925] Trial 61 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.03813922756766748, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:52,300] Trial 62 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.048428277933041115, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:55,907] Trial 63 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.03276866627982984, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:19:59,524] Trial 64 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.1158123670432581, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:02,981] Trial 65 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.06655936376219401, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:06,713] Trial 66 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.01581983305200714, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:10,263] Trial 67 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.08637890961955058, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:13,596] Trial 68 finished with value: 87.48714191239769 and parameters: {'changepoint_prior_scale': 0.09267797937319452, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:17,221] Trial 69 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.1546467641433614, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:20,961] Trial 70 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.3848253915810611, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:24,236] Trial 71 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.05965673370150954, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:28,019] Trial 72 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.04158707918610442, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:31,860] Trial 73 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.06816370831038024, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:35,510] Trial 74 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.011248874574475126, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:39,667] Trial 75 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.03000002934539423, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:43,533] Trial 76 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.055924172566023285, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:47,341] Trial 77 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.13572328608093104, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:50,657] Trial 78 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.19771058537825292, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:54,198] Trial 79 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.07497529557682334, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:20:57,864] Trial 80 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.04541920408953699, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:01,247] Trial 81 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.017002686554734355, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:04,846] Trial 82 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.0026340522065839943, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:08,529] Trial 83 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.023859889002552592, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:11,929] Trial 84 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.014252432799993893, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:15,578] Trial 85 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.03755941187463971, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:19,511] Trial 86 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.02834320526666699, 'seasonality_mode': 'multiplicative'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:22,910] Trial 87 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.05630216231923279, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 87.48714191239759.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:26,735] Trial 88 finished with value: 87.48714191239758 and parameters: {'changepoint_prior_scale': 0.09855703141298447, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:30,301] Trial 89 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.09149981956335315, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:33,792] Trial 90 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.11070508046404262, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:37,308] Trial 91 finished with value: 87.4871419123976 and parameters: {'changepoint_prior_scale': 0.04658910379262692, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:40,866] Trial 92 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.07291299556142004, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:44,140] Trial 93 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.009102362290154488, 'seasonality_mode': 'multiplicative'}. Best is trial 88 with value: 87.48714191239758.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:47,756] Trial 94 finished with value: 87.48714191239756 and parameters: {'changepoint_prior_scale': 0.035198136967558705, 'seasonality_mode': 'additive'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:51,239] Trial 95 finished with value: 87.48714191239759 and parameters: {'changepoint_prior_scale': 0.0960284079083163, 'seasonality_mode': 'multiplicative'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:54,489] Trial 96 finished with value: 87.48714191239758 and parameters: {'changepoint_prior_scale': 0.033507251561531115, 'seasonality_mode': 'additive'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:21:58,304] Trial 97 finished with value: 87.48714191239765 and parameters: {'changepoint_prior_scale': 0.03345834692520434, 'seasonality_mode': 'multiplicative'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:22:01,953] Trial 98 finished with value: 87.48714191239766 and parameters: {'changepoint_prior_scale': 0.049070382845126645, 'seasonality_mode': 'additive'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2024-07-28 10:22:05,345] Trial 99 finished with value: 87.48714191239762 and parameters: {'changepoint_prior_scale': 0.07971819929686436, 'seasonality_mode': 'additive'}. Best is trial 94 with value: 87.48714191239756.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# {'MAE': 77.19999999999996, 'RMSE': 87.48714191239756}

# %% [markdown]
# From the model above and the best parameters chosen by optuna our prophet model has an RMSE of 87.5 and an MAE of 77.2 which is the same with other prophet models.  With that, we will choose the ARIMA model as our final model.

# %% [markdown]
# # ARIMA model.

# %% [markdown]
# We will create an ARIMA model that will help predict the future real estate values in the United States. We will begin by creating a baseline ARIMA model.

# %% [markdown]
# Lets create a function that returns both the RMSE and the MAE of each model.

# %% [markdown]
# For better model evaluation we decide to split our data to have a train and test data

# %%
#Data splitting at 75% of the data
train_size = int(len(df_long) * 0.75) 
train, test = df_long[:train_size], df_long.iloc[train_size:]
print(train.shape)
print(test.shape)
# Out:
# (2562881, 10)
# (854294, 10)

# %%
train = train.apply(pd.to_numeric, errors='coerce')
test = test.apply(pd.to_numeric, errors='coerce')

# %%
#Function to calculate rmse and mae
def metrics(y_test, y_pred):
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    print(f'RMSE: {rmse}\nMAE: {mae}')

# %%
print(train.dtypes)
# Out:
# RegionID            int64
# Zipcode             int64
# City              float64
# State             float64
# Metro             float64
# CountyName        float64
# SizeRank            int64
# Annualized_ROI    float64
# Price             float64
# Rolling_Avg       float64
# dtype: object

# %%
# Dropping null values in the test dataset
train = train.dropna()
test = test.dropna()

# %%
#The baseline model
baseline_model = ARIMA(train, order=(1, 0, 1))
res_arima = baseline_model.fit()
y_hat_baseline = res_arima.predict(start=len(train), end=len(train) + len(test) - 1, typ='levels')
res_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                   15
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 -49.873
# Date:                Sun, 28 Jul 2024   AIC                            107.746
# Time:                        12:53:55   BIC                            110.578
# Sample:                    01-31-2020   HQIC                           107.716
#                          - 03-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.0000     71.143      1.124      0.261     -59.438     219.438
# ar.L1          0.9894      0.078     12.764      0.000       0.838       1.141
# ma.L1          0.9982     52.903      0.019      0.985    -102.689     104.686
# sigma2        26.6786   1401.108      0.019      0.985   -2719.443    2772.800
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.83   Jarque-Bera (JB):                68.40
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                            -3.08
# Prob(H) (two-sided):                  1.00   Kurtosis:                        11.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Checking the metrics of the model.
metrics(test, y_hat_baseline)
# Out:
# RMSE: 31.267867349257212
# MAE: 27.30591750915289

# %% [markdown]
# From the baseline model we have an RMSE of 31.27 and a Mean Absolute Error of 27.31, which is not a bad score but to try and improve it we tried a different model. We will go ahead and create an ARIMA(1, 3) model.

# %%
# Second ARIMA model
model2 = ARIMA(train, order=(1, 0, 3))
res_arima2 = model2.fit()
y_hat_2 = res_arima2.predict(start=len(train), end=len(train) + len(test) - 1, typ='levels')
res_arima2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                   15
# Model:                 ARIMA(1, 0, 3)   Log Likelihood                 -36.505
# Date:                Sun, 28 Jul 2024   AIC                             85.010
# Time:                        12:54:35   BIC                             89.258
# Sample:                    01-31-2020   HQIC                            84.965
#                          - 03-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.0000    131.542      0.608      0.543    -177.818     337.818
# ar.L1          0.9906      0.089     11.193      0.000       0.817       1.164
# ma.L1          2.6096   1130.609      0.002      0.998   -2213.344    2218.563
# ma.L2          2.6090   1735.841      0.002      0.999   -3399.578    3404.796
# ma.L3          0.9994   1096.129      0.001      0.999   -2147.374    2149.373
# sigma2         2.3103   2533.242      0.001      0.999   -4962.753    4967.374
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.92   Jarque-Bera (JB):                26.28
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -2.07
# Prob(H) (two-sided):                  0.80   Kurtosis:                         7.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Checking the metrics
metrics(test, y_hat_2)
# Out:
# RMSE: 22.817600584508018
# MAE: 18.50781246144728

# %% [markdown]
# The second ARIMA model has an RMSE of 22.81 and MAE of 18.50 which is slightly better than the baseline model. We will then try an ARIMA(3,1) model to see if our model improves.

# %%
# Third ARIMA model
model3 = ARIMA(train, order=(3, 0, 1))
res_arima3 = model3.fit()
y_hat_3 = res_arima3.predict(start=len(train), end=len(train) + len(test) - 1, typ='levels')
res_arima3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                   15
# Model:                 ARIMA(3, 0, 1)   Log Likelihood                  15.678
# Date:                Sun, 28 Jul 2024   AIC                            -19.355
# Time:                        11:03:26   BIC                            -15.107
# Sample:                    01-31-2020   HQIC                           -19.400
#                          - 03-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         80.0000     48.689      1.643      0.100     -15.428     175.428
# ar.L1          0.9994    102.734      0.010      0.992    -200.355     202.354
# ar.L2          0.9994    205.404      0.005      0.996    -401.586     403.585
# ar.L3         -0.9999    102.728     -0.010      0.992    -202.342     200.343
# ma.L1          0.9997    512.299      0.002      0.998   -1003.088    1005.087
# sigma2         0.0018      0.753      0.002      0.998      -1.475       1.478
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):                13.13
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.19   Skew:                             1.70
# Prob(H) (two-sided):                  0.09   Kurtosis:                         6.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Checking the metrics
metrics(test, y_hat_3)
# Out:
# RMSE: 0.3963682066278426
# MAE: 0.31611338815408774

# %% [markdown]
# The third model, ARIMA(3,0,1) has an RMSE of 0.40 and MAE of 0.35 which is better than the second model.

# %% [markdown]
# The final ARIMA model performs better than all the other models. This is because both the RMSE and the MAE of this model are lower compared to the others.
#
# However, the main issue with the ARIMA model is that it relies on stationarity, homoscedasticity and normality and the data does not follow a normal distribution. The AIC and BIC scores for the models are too big.

# %% [markdown]
# With that and compared to the prohet Model we will choose the ARIMA model as our final model.

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1.Prioritize High-ROI Areas: Focus on high-ROI regions like DC and Brooklyn's 11211 for significant portfolio allocation.
#
# 2.Diversify Investments: Balance your portfolio by including properties from high-ROI areas and stable markets to mitigate risks.
#
# 3.Analyze Outliers: Include some outlier properties after thorough analysis to take advantage of unique investment opportunities.
#
# 4.Regional Focus: Invest in zip codes with consistent growth trends like 11211, 11222, 11216, and 07302, while considering the risk tolerance and desired growth rate.

# %% [markdown]
# # Recommendation

# %% [markdown]
# 1.From our finding it is advisable to invest in Real Estate, the data showed an upward trend, indicating appreciating values over the years.
#
# 2.To potential real estate investors, we recommend investing in the following states, New York, New Jersey, Colorado, Carlifornia and Washington DC, from the analysis these states showed promising Returns on Investment. The best zipcodes were found within the states mentioned, these are, 11211 - Brooklyn, New York, 11222 - Brooklyn, New York, 11216 - Brooklyn, New York, 7302 - Jersey City, New Jersey and 11215 - Brooklyn, New York.
#
# 3.As a way to mitigate risk we recommend using the model created to forecast future values of Real Estate. This will help in giving accurate future Real Estate values.

# %% [markdown]
# # Saving the model

# %%
# Save the model using joblib
with open('arima_model.pkl', 'wb') as f:
    joblib.dump(final_ARIMA_model, f)
